# %% [markdown]
# # What is Unsupervised learning???

# %% [markdown]
# ### In unsupervised learning,we train the machine using data which is "unlabeled" and models itself find the hidden patterns and insights from the given data
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # How does unsupervised learning works???

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### এখন আমাদের কাছে unknown data আছে । মানে আমি জানি না যে কি আছে । এখন আমাদের model কিভাবে detect করবে আগে তো class ছিল Supervised learning এ ।
# ### এটা detect করে previous pattern থেকে। মানে এখানে sunflower and rose আছে। এখন এদের আলাদা catagory আছে।like sunflower e কাঁটা নাই ।Rose এ আছে এরকম।
# ### Then it will apply algorithm.

# %% [markdown]
# # Type of Unsupervised learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Unsupervised algorithm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Advantages of unsupervised learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Disadvantages of unsupervised learning

# %% [markdown]
# ![image.png](attachment:image.png)
