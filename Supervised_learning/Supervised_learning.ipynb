# %% [markdown]
# # Supervised learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Type of Supervised learning

# %% [markdown]
# ### Regression

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Classification

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
