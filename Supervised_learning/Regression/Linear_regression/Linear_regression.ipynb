# %% [markdown]
# # Linear Regression

# %% [markdown]
# Linear Regression is a machine learning algorithm based on supervised learning.
#
# It is statistical method that is used for predictive analysis.
# Linear regression makes predictions for continuous/real numeric variables such as cost,age,sales,temperature,product etc.

# %% [markdown]
# # Types of Linear Regression

# %% [markdown]
# ### 1.Linear Regression with Single Variable(Simple linear regression).
#
# ### 2.Linear Regression with Multiple Variables(multiple linear regression).

# %% [markdown]
# # Assumptions of linear regression

# %% [markdown]
# ### 1.Linearity:
# ![image.png](attachment:image.png)
#
# ### 2.Hornoscedasticity:
#
# ![image-2.png](attachment:image-2.png)
#
# ### 3.Multivariate Normality:
#
# ![image-3.png](attachment:image-3.png)
#
# ### 4.Independence:
#
# ![image-4.png](attachment:image-4.png)
#
# ### 5.Lack of Multicoliinearity:
#
# ![image-5.png](attachment:image-5.png)
#
# ### 6.The outlier check:
#
# This is not an assumption,but an "extra" means there is a point which is not like in the simple like outside.
#
# ![image-6.png](attachment:image-6.png)
