# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ### Model statement

# %% [markdown]
# এখানে আমি linear regression use করে model কে train করাব যাতে করে year_experience and salary এর মধ্যে corelation টা model কে train করানো যায়।
# And new employee এর salary predict করতে পারে previous train data থেকে।

# %% [markdown]
# ### Import libraries
# ***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Getting dataset
# ***

# %%
dataset=pd.read_csv("Salary_Data.csv")

# %%
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# ### importing datasets
# ***

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
print(x)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
print(y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %% [markdown]
# ### Finding missing values
# ***

# %% [markdown]
# ### Encoding Catagorical Data
# ***

# %% [markdown]
# ### Splitting dataset into Training & Test set
# ***

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=.2,random_state=0)

# %% [markdown]
# ### Feature Scaling
# ***

# %% [markdown]
# ### Training the Simple linear regression model on the training set
# ***

# %%
from sklearn.linear_model import  LinearRegression
regressor=LinearRegression();
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting the test set results
# ***

# %%
y_pred=regressor.predict(X_test)

# %%
print(y_pred)
# Out:
# [ 40748.96184072 122699.62295594  64961.65717022  63099.14214487
#  115249.56285456 107799.50275317]

# %% [markdown]
# ### Predicting the model accuracy

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,y_pred)
# Out:
# 0.988169515729126

# %% [markdown]
# ### The best-fit line:
# এখন LINE ত অনেকভাবে হতে পারে।
#
# এখন সেটা কিভাবে select করব। The best-fit line will have the least error.
#
# Least error= min(sum of((data value - line er point)^2)
#
# Y=mX+c
#
# where
#
# Y=dependent variable
#
# X=Independent variable
#
# M=slope/gradient/coefficient
#
# c=intercept

# %% [markdown]
# ### vistualising the training set results

# %%
plt.scatter(X_train,Y_train,color="red")
plt.plot(X_train,regressor.predict(X_train),color="blue")
plt.title("Salary vs Experience(Training set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ### vistualising the test set results

# %%
plt.scatter(X_test,Y_test,color="red")
plt.plot(X_test,regressor.predict(X_test),color="blue")
plt.title("Salary vs Experience(Test set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()
