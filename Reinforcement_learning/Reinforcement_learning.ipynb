# %% [markdown]
# # Reinforcement learning

# %% [markdown]
# ### What is it!!!

# %% [markdown]
# Recently in chess game ai defeat the number 1 chess player .But we just give the ai some basic instraction of chess like how to play chess.
#
# ### Now question is how do it do that??
# By using reinforcement learning.
#
# For an example:
#
# ![image.png](attachment:image.png)
#
# in this game we put many obstacle in the way of this object.
# Now when it cross the obstacle it gain +1 point.
# otherwise point deducted.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# For this reward our ML model Or deep learning model train itself .

# %% [markdown]
# # Components of Reinforcement learning

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
