# %% [markdown]
# ![image.png](attachment:image.png)
#
# There is a liver and some reels .When we use liver the movement of reels activated.
# As there is one liver .so we call it one armed bandit
#
# here bandit means people who play in those machine they lose a lot of money than gain money
#
# So multi armed bandit means
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# এখন যখন আমি একটা person এর test এর উপর কোন medicine ভাল না খারাপ।কিন্তু হতে পারে ওই person এর জন্য অন্য medicine কাজ করে নাই।কিন্তু অন্য গুলার যেকোনো একটার accuracy better.

# %% [markdown]
# এখানে
#
# doctor=> agent
#
#
# bandit => medicine(option)

# %% [markdown]
# # Action-Values

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Action => which medicine i apply
#
# Values => the reaction of the person body
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
