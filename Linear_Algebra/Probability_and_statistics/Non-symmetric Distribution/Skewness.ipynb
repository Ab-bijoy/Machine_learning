# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# If i apply Machine learning model in this graph.We will face outlier problem.BCZ the frequency of high cost car is so less.
# This will cause outlier.Thats why we calculate skewness.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# if mode=median=mean this is symmetric
