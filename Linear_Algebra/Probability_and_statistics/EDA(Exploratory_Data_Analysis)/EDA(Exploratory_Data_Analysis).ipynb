# %% [markdown]
# ### Youtube:
# https://www.youtube.com/watch?v=uuF6z0Yt2Wk&list=PLPzjifo9TUNX8UKgRBKgMGF5nYB_uEe0h&pp=iAQB

# %% [markdown]
# # EDA
#
# কোন data এর উপর যদি আমাদের machine learning model apply করতে হয়  তাহলে আমরা আগে data analysis করে দেখতে হবে।
#
# ## EDA কিভাবে করতে হয়?
#
# ### 1. Data Loading
#
# ### 2. Data Inspection
#
# ### 3. Data Cleaning
#
# ###

# %% [markdown]
# For an example:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Import Liberaies

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Import Dataset

# %%
iris = pd.read_csv("IRIS.csv")

# %%
iris

# %% [markdown]
# ### How many data-points and features

# %%
print(iris.shape)

# %% [markdown]
# ### What are the column names in our dataset

# %%
print(iris.columns)

# %% [markdown]
# ### How many data points for each class are present?
# ### How name fower for each species are present?

# %%
iris["species"].value_counts()

# %% [markdown]
# ### Balanced-dataset vs imbalanced datasets
# ### iris is a balanced dataset as the number of data points for every class is 50

# %%
iris.plot(kind='scatter', x="sepal_length", y="sepal_width")
plt.show()

# %% [markdown]
# ### Mapping

# %% [markdown]
# এখানে যেটা করসি
#
# FOR AN EXAMPLE:
#
# sepal_length=5 and sepal_width=20
# এখন species এ আমি খুজব or map করব sepal_length=5 and sepal_width=20 কোন species এর
# সেটা হল versicolor . so here we will see orange point

# %%
sns.set_style("whitegrid")
sns.FacetGrid(iris,hue="species" )\
    .map(plt.scatter, "sepal_length", "sepal_width")\
        .add_legend();
plt.show()

# %% [markdown]
# ### Pair plot
# ![image.png](attachment:image.png)

# %%
sns.set_style("whitegrid")
sns.pairplot(iris,hue="species")
plt.show()

# %% [markdown]
# # Histogram

# %%
iris_setosa=iris.loc[iris["species"]=='Iris-setosa']
iris_virginica=iris.loc[iris["species"]=="Iris-virginica"]
iris_versicolor=iris.loc[iris["species"]=="Iris-versicolor"]
plt.plot(iris_setosa["petal_length"],np.zeros_like(iris_setosa['petal_length']),'o')
plt.plot(iris_versicolor["petal_length"],np.zeros_like(iris_versicolor['petal_length']),'d')
plt.plot(iris_virginica["petal_length"],np.zeros_like(iris_virginica['petal_length']),'p')

# %%
sns.FacetGrid(iris,hue="species" )\
    .map(sns.distplot, "petal_length",)\
        .add_legend();
plt.show()

# %% [markdown]
# ### Probabilty density function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Cumulative Distribution Function

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
counts,bin_edges=np.histogram(iris_setosa['petal_length'],bins=10,density=True)

pdf1=counts/(sum(counts))
print(pdf1)
print(bin_edges)

counts,bin_edges=np.histogram(iris_versicolor['petal_length'],bins=10,density=True)

pdf2=counts/(sum(counts))
print(pdf2)
print(bin_edges)

counts,bin_edges=np.histogram(iris_virginica['petal_length'],bins=10,density=True)

pdf3=counts/(sum(counts))
print(pdf3)
print(bin_edges)

# %% [markdown]
# ### Compute CDF

# %%
cdf1=np.cumsum(pdf1)
cdf2=np.cumsum(pdf2)
cdf3=np.cumsum(pdf3)

plt.plot(bin_edges[1:],pdf1)
plt.plot(bin_edges[1:],cdf1)

plt.plot(bin_edges[1:],pdf2)
plt.plot(bin_edges[1:],cdf2)

plt.plot(bin_edges[1:],pdf3)
plt.plot(bin_edges[1:],cdf3)


plt.xlabel("Petal_length")
plt.ylabel("Probability")
plt.show()

# %% [markdown]
# ### Mean and Standard Deviation(variance)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# variance represent the area of the points lay in the graph
#
# Standard deviation represent what are the flower that have much similar and what are the flower that have less similar.

# %% [markdown]
# ### Means

# %%
print(np.mean(iris_setosa["petal_length"]))

# %% [markdown]
# ### Means with an outlier(unexpected data)

# %%
print(np.mean(np.append(iris_setosa["petal_length"],50)))
print(np.mean(iris_virginica["petal_length"]))
print(np.mean(iris_versicolor["petal_length"]))

# %% [markdown]
# ### Standard deviation

# %%
print(np.std(iris_setosa["petal_length"]))
print(np.std(iris_virginica["petal_length"]))
print(np.std(iris_versicolor["petal_length"]))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Median
#
# ![image.png](attachment:image.png)

# %%
print(np.median(iris_setosa["petal_length"]))

# %% [markdown]
# ### Median with an outlier

# %%
print(np.median(np.append(iris_setosa["petal_length"],50)))
print(np.median(iris_virginica["petal_length"]))
print(np.median(iris_versicolor["petal_length"]))

# %% [markdown]
# ### Median Absolute Deviation(MAD)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from statsmodels import robust

print(robust.mad(iris_setosa["petal_length"]))
print(robust.mad(iris_virginica["petal_length"]))
print(robust.mad(iris_versicolor["petal_length"]))

# %% [markdown]
# ### Percentile
#
# 50 percentile means we talk about 50%.

# %%
print(np.percentile(iris_setosa["petal_length"],90))
print(np.percentile(iris_virginica["petal_length"],90))
print(np.percentile(iris_versicolor["petal_length"],90))

# %% [markdown]
# ### Quantiles
#
# data will divide into 4 parts.

# %%
print(np.percentile(iris_setosa["petal_length"],np.arange(0,100,25)))
print(np.percentile(iris_virginica["petal_length"],np.arange(0,100,25)))
print(np.percentile(iris_versicolor["petal_length"],np.arange(0,100,25)))

# %% [markdown]
# ### Box Plot
#
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x='species',y='petal_length',data=iris)
plt.legend()

# %% [markdown]
# ### Violin Plot

# %%
sns.violinplot(x='species',y='petal_length',data=iris)
plt.show()

# %% [markdown]
# ### Analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Univariant:
# Here only one variable or one variant
#
# ### bivariant:
#
# 2 variable or 2 variant
#
# ### Multi-variant
#
# multi everything
