# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Standard Normal Variate
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Why we need Z

# %% [markdown]
# in Gaussian distribution we easily tell the percentage .But we can not do in other distribution.For those, we use Z

# %% [markdown]
# ### Sampling Distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We convert it in gaussian distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Whwn we plot this mean in graph we will see that in gaussianly distributed

# %% [markdown]
# CLT(Central limit theorem)

# %% [markdown]
# ![image.png](attachment:image.png)
