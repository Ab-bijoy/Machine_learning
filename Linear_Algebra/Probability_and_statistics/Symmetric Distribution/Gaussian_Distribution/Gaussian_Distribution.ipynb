# %% [markdown]
# # Gaussian Distribution
#
# ![image.png](attachment:image.png)

# %% [markdown]
# u হচ্ছে mean . u এর মান দেয়া মানে হচ্ছে top টা দেয়া middle থেকে।
# omega => variance represent the area of the points lay in the graph

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### PDF in GAUSSIAN DISTRIBUTION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### CDF in GAUSSIAN DISTRIBUTION

# %% [markdown]
# ![image.png](attachment:image.png)
